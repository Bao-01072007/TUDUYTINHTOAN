# %% [markdown]
# ### W6A1
# Nhập vào một dòng gồm các số nguyên. Hãy loại bỏ phần tử trùng nhưng
# giữ nguyên thứ tự xuất hiện đầu tiên, rồi in ra list kết quả.
# Yêu cầu in ra đúng dạng list Python, ví dụ [1, 2, 3]

# %%
lst = list(map(int, input().split()))
s = []  # Tạo 1 list rỗng
for i in lst:
    if i not in s:
        s.append(i)
print(s)
# Out:
# [1, 2, 3, 7, 9, 8, 5]

# %% [markdown]
# ### W6A2
# Nhập một dòng số nguyên. In ra list tổng tích lũy (phần tử i là tổng từ đầu
# tới vị trí i), giữ nguyên thứ tự

# %%
lst = list(map(int, input().split()))
s = []
tong = 0
for i in lst:
    tong += i
    s.append(tong)
print(s)
# Out:
# [1, 3, 6]

# %% [markdown]
# ### W6A3
# Nhập một tuple số nguyên (một dòng) và số nguyên k (dòng kế). In ra tuple
# sau khi xoay trái k vị trí. (Giữ nguyên thứ tự tương đối sau xoay; không sắp
# xếp.)

# %%
tup = tuple(map(int, input().split()))
k = int(input())
n = len(tup)
if n>0:
    k = k%n  # Giả sử xoay 4 vị trí, thì chỉ cần xoay 1 vị trí thôi vì xoay 4 hay 1 lần đều giống nhau
    kq = tup[k:] + tup[:k]
    print(kq)
else:
    print("Tuple rỗng")

# %% [markdown]
# ### W6A4
# Nhập một dòng gồm các cặp key:value cách nhau bởi dấu cách. Tạo
# dictionary ánh xạ mỗi key -> list các value theo thứ tự xuất hiện. Nếu key
# lặp lại, thêm vào list của key đó

# %%
lst = list(map(str, input("Nhập các cặp key:value").split()))
s = {} # Tạo 1 dict rỗng
for i in lst:
    key, value = i.split(':')
    if key not in s:
        s[key]=[]  # Check nếu key chưa có trong dict thì tạo 1 list rỗng cho key
    s[key].append(value)
print(s)
# Out:
# {'A': ['1', '2'], 'B': ['2', '4']}

# %% [markdown]
# ### W6A5
# Nhập một list số nguyên, In ra dictionary {'positives': ..., 'negatives': ...,
# 'zeros': ...} (đếm số >0, <0, =0)

# %%
lst = list(map(int, input().split()))
dem = {'positives': 0, 'negatives': 0, 'zeros': 0} # Tạo ra một dict với các giá trị ban đầu bằng 0
for i in lst:
    if i > 0:
        dem['positives'] += 1
    elif i < 0:
        dem['negatives'] += 1
    else:
        dem['zeros'] += 1
print(dem)
# Out:
# {'positives': 1, 'negatives': 1, 'zeros': 1}

# %% [markdown]
# ### W6A6
# Viết chương trình nhập vào một danh sách các số nguyên, sau đó in ra tổng các số trong list đó.

# %%
lst = list(map(int, input().split()))
tong = 0
for i in lst:
    tong += i
print(tong)
# Out:
# 3

# %% [markdown]
# ### W6A7
# Viết chương trình nhập vào một tuple, in ra phần tử đầu, phần tử cuối, và
# tuple đảo ngược

# %%
tup = tuple(input().split())
n = len(tup)
if n > 0:
    phan_tu_dau = tup[0]
    phan_tu_cuoi = tup[-1]
    dao_nguoc = tup[::-1]
    print(phan_tu_dau)
    print(phan_tu_cuoi)
    print(dao_nguoc)
else:
    print("Rỗng")
# Out:
# 1
# b
# ('b', '3', '2', '1')

# %% [markdown]
# ### W6A8
# Viết chương trình nhập vào một list các chuỗi, sau đó đếm số lần xuất hiện
# của từng chuỗi và lưu vào dictionary.

# %%
lst = list(input().split())
dist = {}
for i in lst:
    if i in dist:
        dist[i] += 1
    else:
        dist[i] = 1
print(dist)
# Out:
# {'1': 3, '2': 2, '3': 1}

# %% [markdown]
# ### W6A9
# Viết chương trình nhập vào hai dictionary. Sau đó gộp lại thành một
# dictionary mới trong đó nếu một key xuất hiện trong cả hai dict, giá trị sẽ
# được cộng lại, nếu chỉ có trong một dict thì giữ nguyên. In ra dictionary mới
# theo thứ tự từ điển tăng dần của key.

# %%
# Hàm để nhập và chuyển đổi chuỗi thành dict
def chuoi_thanh_dict(label):
    chuoi = input().split()
    dict = {}
    for i in chuoi:
        k, v = i.split(':')
        # Chuyển value sang số nguyên để có thể cộng
        dict[k] = int(v)
    return dict
# Nhập 2 dict
dict1 = chuoi_thanh_dict("dict1")
dict2 = chuoi_thanh_dict("dict2")
# Gộp
# Tạo bản sao của dict1
s = dict1.copy()
for key, value in dict2.items(): # Duyệt qua từng phần tử của dict2 bằng .items()
    if key in s:
        s[key] += value  # Nếu đã có key thì cộng với value
    else:
        s[key] = value
# Sắp xếp dict
sap_xep_key = sorted(s.keys())  # Sắp xếp key
sorted_dict = {}
for k in sap_xep_key:
    sorted_dict[k] = s[k]
print(sorted_dict)
# Out:
# {'a': 2, 'b': 3, 'c': 3}

# %% [markdown]
# ### W6A10
# Viết chương trình nhập vào một danh sách các số nguyên, và số nguyên
# dương k. In ra list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là
# một tuple, hai số trong tuple có thể giống nhau, thứ tự xuất hiện trong danh
# sách của số thứ nhất nhỏ hơn thứ tự của số thứ hai. Các tuple trong list được
# sắp xếp theo thứ tự tăng dần của phần tử đầu tiên trong tuple.

# %%
lst = list(map(int, input().split())) # Nhập danh sách các số nguyên
k = int(input())
temp = []  # Tạo 1 list rỗng
n = len(lst)
for i in range(n):
    for j in range(i+1, n): # Để dảm bảo thứ tự xuất hiện số thứ nhất nhỏ hơn số thứ 2
        if lst[i] + lst[j] == k:
            temp.append((lst[i], lst[j]))  # lưu các cặp số dưới dạng tuple
# Lọc các cặp số trùng nhau, và lưu thành 1 list mới
danh_sach_khac_nhau = list(set(temp))
# sắp xếp tăng dần theo phần tử đầu tiên của tuple
danh_sach_khac_nhau.sort()
print(danh_sach_khac_nhau)
# Out:
# [(2, 2), (3, 1)]

# %% [markdown]
# ### W6A11
# [Tách số chẵn và lẻ từ tuple]
# Nhập vào một tuple chứa các số nguyên. Hãy tạo ra hai tuple mới: một chứa
# tất cả các số chẵn và một chứa tất cả các số lẻ từ tuple ban đầu, giữ nguyên
# thứ tự tương đối. In ra hai tuple này trên hai dòng riêng biệt.

# %%
tup = tuple(map(int, input().split()))
tup_chan = []  # List rỗng
tup_le = []    # List rỗng
for i in tup:
    if i%2 == 0:
        tup_chan.append(i)
    else:
        tup_le.append(i)
# Đề bài yêu cầu in ra tuple, nên chuyển list thành tuple
tup_chan = tuple(tup_chan)
tup_le = tuple(tup_le)
print(tup_chan)
print(tup_le)
# Out:
# (2, 4, 6)
# (1, 3, 5, 7)

# %% [markdown]
# ### W6A12
# [Tìm phần tử xuất hiện nhiều nhất]
# Nhập vào một list các số nguyên. Hãy tìm số xuất hiện nhiều lần nhất trong
# list. Nếu có nhiều số cùng có số lần xuất hiện nhiều nhất, hãy in ra số nhỏ
# nhất trong số đó.

# %%
lst = list(map(int, input().split()))
# Dùng dict để đếm số lần xuất hiện của 1 số
dem = {}
for i in lst:
    if i in dem:
        dem[i] += 1   # Giá trị i thêm 1 lần xuất hiện
    else:
        dem[i] = 1 # Nếu chưa xuất hiện thì coi đây là lần 1
# Tìm số xuất hiện nhiều nhất
xuat_hien_max = 0
for i in dem:
    if dem[i] > xuat_hien_max:
        xuat_hien_max = dem[i]

# Các số cùng số lần xuất hiện nhiều nhất
ds_xuat_hien_max = []
for i in dem:
    if dem[i] == xuat_hien_max:
        ds_xuat_hien_max.append(i)
ket_qua = ds_xuat_hien_max[0]
for x in range(1, len(ds_xuat_hien_max)):
    if ds_xuat_hien_max[x] < ket_qua:
        ket_qua = ds_xuat_hien_max[x]
print(ket_qua)
# Out:
# 3

# %% [markdown]
# ### W6A13
# [Đảo ngược key và value của dictionary]
# Nhập vào một dictionary có value là duy nhất (không trùng nhau). Hãy tạo
# một dictionary mới bằng cách đảo ngược key và value của dictionary ban
# đầu. In ra dictionary mới.

# %%
# Muốn nhập vào 1 dict thì ban đầu cứ nhập vào 1 chuỗi sau đó tách từng key:value sau
s = map(str, input().split())
dict_ban_dau = {}
# Giờ mới bắt đầu chuyển chuỗi thành dict
for i in s:
    k, v = i.split(':')
    dict_ban_dau[k] = v

# 2. Tạo dictionary mới bằng cách đảo ngược
dict_dao_nguoc = {}
for k, v in dict_ban_dau.items(): # Muốn tách từng k:v của dict phải dùng items()
    # Gán value của dict cũ làm key cho dict mới
    dict_dao_nguoc[v] = k
print(dict_dao_nguoc)
# Out:
# {'1': 'a', '3': 'b', '2': 'c'}

# %% [markdown]
# ### W6A14
# [Giao của hai danh sách]
# Nhập vào hai dòng, mỗi dòng là một danh sách các số nguyên. Hãy tìm các phần tử chung (giao) của hai danh sách này và in ra một list mới chứa các
# phần tử chung đó, không trùng lặp.

# %%
lst_1 = list(map(int, input().split()))
lst_2 = list(map(int, input().split()))
# Loại bỏ các phần tử trùng lặp của list
lst_1 = set(lst_1)
lst_2 = set(lst_2)
lst_chung = []
for i in lst_1:
    if i in lst_2:
        lst_chung.append(i)
print(lst_chung)
# Out:
# [1, 2]

# %% [markdown]
# ### W6A15
# [Lọc dictionary theo giá trị]
# Nhập vào một dictionary có key là chuỗi và value là số nguyên, và một số
# nguyên k ở dòng tiếp theo. Hãy tạo một dictionary mới chỉ chứa các cặp
# key-value từ dictionary ban đầu mà có value lớn hơn k. In ra dictionary
# mới.

# %%
s = map(str, input().split())
k = int(input())
dict_ban_dau = {}
for i in s:
    key, value = i.split(':')
    value = int(value)
    key= str(key)
    dict_ban_dau[key] = value
dict_moi = {}
for key, value in dict_ban_dau.items():
    if value > k:
        dict_moi[key] = value
print(dict_moi)
# Out:
# {'b': 2, 'c': 2, 'd': 3}

# %% [markdown]
# ### W6A16
# Nhập vào mảng n hàng, m cột số nguyên. In lại mảng ra màn hình như ma
# trận hai chiều, định dạng mỗi phần tử 4 vị trí căn phải

# %%
# 1. Nhập số hàng n và số cột m
n = int(input("Nhập số hàng n: "))
m = int(input("Nhập số cột m: "))

# 2. Nhập ma trận
ma_tran = []
for i in range(n):
    # Nhập cả hàng trên một dòng, cách nhau bởi dấu cách
    hang = list(map(int, input(f"Nhập hàng {i+1}: ").split()))
    ma_tran.append(hang)

# 3. In ma trận với định dạng căn phải 4 vị trí
print("\nMa trận kết quả:")
for hang in ma_tran:
    for phan_tu in hang:
        # :4d nghĩa là định dạng số nguyên (d), độ rộng 4, mặc định căn phải
        print(f"{phan_tu:4d}", end="")
    print() # Xuống dòng sau khi in hết một hàng
# Out:
# Ma trận kết quả:
#    1   2
#    1   3

# %%
n = int(input("Nhập số hàng:"))
m = int(input("Nhập số cột:"))
ma_tran = []
for i in range(n):
    hang = list(map(int, input().split()))
    ma_tran.append(hang)
for hang in ma_tran:
    for phan_tu in hang:
        print(f"{phan_tu:4d}", end ="") # :4d nghĩa là định dạng số nguyên (d), độ rộng 4, mặc định căn phải
    print()  # Xuống dòng sau khi hết 1 hàng
# Out:
#    1   2   3
#    1   3   4
#    3   5   6

# %% [markdown]
# ### W6A17
# Nhập vào mảng vuông 2 chiều n hàng, n cột, in ra đường chéo chính và
# đường chéo phụ của mảng

# %%
n = int(input())
ma_tran = []
for i in range(n):
    hang = list(map(int, input().split()))
    ma_tran.append(hang)
# Lấy các đường chéo
# Đường chéo chính, hàng i và cột i
duong_cheo_chinh = []
for i in range(n):
    duong_cheo_chinh.append(ma_tran[i][i])
duong_cheo_phu = []
for i in range(n):
    duong_cheo_phu.append(ma_tran[i][n-i-1])
print(f"Đường chép chính: {duong_cheo_chinh}")
print(f"Đường chéo phụ: {duong_cheo_phu}")
# Out:
# Đường chép chính: [1, 2]
# Đường chéo phụ: [2, 1]

# %% [markdown]
# ### W6A18
# Nhập vào mảng n hàng, m cột số nguyên và số nguyên k (n, m, k nhập trên ̣
# cùng một dòng, cách nhau dấu cách). Tính và in ra tổng các phần tử trên cột
# k (hàng k)

# %%
n, m, k = map(int, input().split())
# Tạo ma trận
ma_tran = []
for i in range(n):
    hang = list(map(int, input().split()))
    ma_tran.append(hang)
# Tính tổng các phần tử trên hàng k (Chỉ số cột từ 0 đến m-1)
tong_hang_k = 0
if 0 <= k < n:
    for j in range(m):
        tong_hang_k += ma_tran[k][j]
    print(f"Tổng các phần tử trên hàng {k} là: {tong_hang_k}")
else:
    print("Không tồn tại")
tong_cot_k = 0 # Các chỉ số của hàng từ 0 đến n-1
if 0<= k < m:
    for z in range(n):
        tong_cot_k += ma_tran[z][k]
    print(f"Tổng các phần tử trên cột {k} là: {tong_cot_k}")
else:
    print("Không tồn tại")
# Out:
# Không tồn tại
# Không tồn tại

# %% [markdown]
# ### W6A19
# Viết hàm đưa vào 1 list số nguyên, tìm và trả về vị trí có giá trị lớn nhất
# trong list

# %%
lst = list(map(int, input().split()))
vi_tri_max = 0
for i in range(1, len(lst)):
    if lst[i] > lst[vi_tri_max]:
        vi_tri_max = i
print(vi_tri_max)
# Out:
# 4

# %%
lst = list(map(int, input().split()))
sln = lst[0]
for i in lst:
    if i > sln:
        sln = i
print(sln)
# Out:
# 4

# %% [markdown]
# ### W6A20
# Viết hàm đưa vào một list số nguyên và một số nguyên dương k. Hãy tìm và
# trả về vị trí của phần tử đầu tiên có giá trị k trong list, nếu không có thì trả về
# -1

# %%
lst = list(map(int, input().split()))
k = int(input())
if k in lst:
    for i in range(len(lst)):
        if lst[i] == k:
            print(i)
else:
    print(-1)
# Out:
# -1

# %% [markdown]
# ### W6A21
# Nhập một dòng gồm các chuỗi (tách bởi dấu cách). Tạo dictionary ánh xạ
# chuỗi -> tuple các vị trí (0-based) mà chuỗi đó xuất hiện

# %%
lst = input().split()
dict = {}
for i in range(len(lst)):
    phan_tu = lst[i]
    if phan_tu not in dict:
        dict[phan_tu] = [i]
    else:
        dict[phan_tu].append(i)
for phan_tu in dict:
    dict[phan_tu] = tuple(dict[phan_tu])
print(dict)
# Out:
# {'b': (0,), 'a': (1,), 'o': (2,)}

# %% [markdown]
# ### W6A22
# Viết hàm đưa vào 1 list số nguyên, tìm và trả về vị trí có giá trị lớn nhất
# trong list

# %%
lst = list(map(int, input().split()))
sln = lst[0]
for i in lst:
    if i > sln:
        sln = i
print(sln)
# Out:
# 9

# %% [markdown]
# ### W6A23
# VIết hàm xóa đi các số <x có trong mảng

# %%
lst = list(map(int, input().split()))
x = int(input())
ds = []
for i in lst:
    if i >= x:
        ds.append(i)
print(ds)
# Out:
# [5]

# %% [markdown]
# ### W6A24
# Viết hàm đẩy tất cả các số 0 về đầu (về cuối), các số khác vẫn đúng vị trí
# trước sau: 0 2 3 2 4 0 0 0 9 => 0 0 0 2 3 2 4 9

# %%
def day_so_0_len_dau(lst):
    khong = []
    khac_khong = []
    for i in lst:
        if i == 0:
            khong.append(i)
        else:
            khac_khong.append(i)
    return(khong + khac_khong)
# Test
lst = list(map(int, input().split()))
print(day_so_0_len_dau(lst))
# Out:
# [0, 0, 0, 1, 2, 3, 4, 5]

# %% [markdown]
# ### W6A25
# Cho dãy chỉ gồm N giá trị từ 0 - 9 . Kiểm tra xem giá trị nào không có trong
# mảng

# %%
day = list(map(int, input().split()))
khong_co =[]
for i in range(10):
    if i not in day:
        khong_co.append(i)
print(khong_co)
# Out:
# [0, 7]

# %% [markdown]
# ### W6A26
# Tính tổng các phần tử cực đại địa phương trong một danh sách, không tính 2
# phần tử đầu và cuối

# %%
lst = list(map(int, input().split()))
tong = 0
n = len(lst)
for i in range(1, n-1): # Bỏ phần từ đầu và cuối
    if lst[i] > lst[i-1] and lst[i] > lst[i+1]:
        tong += lst[i]
print(tong)
# Out:
# 12

# %% [markdown]
# ### W6A27
# Cho một dãy số nguyên, Tìm và in ra vị trí các số < x (x là giá trị cho trước).
# nếu không có in ra -1

# %%
lst = list(map(int, input().split()))
x = int(input())
ds = []
if x not in lst:
    print(-1)
else:
    for i in range(len(lst)):
        if lst[i] < x:
            ds.append(i)
    print(ds)
# Out:
# [0, 1, 2]

# %% [markdown]
# ### W6A28
# Cho một dãy các số nguyên, kiểm tra xem nó là dãy tăng thực sự hay giảm
# thực sự, hay vô danh (không tăng, không giảm)

# %%
lst = list(map(int, input().split()))
day_tang = True
day_giam = True
for i in range(len(lst)-1):
    if lst[i] >= lst[i+1]:
        day_tang = False
    if lst[i] <= lst[i+1]:
        day_giam = False
if day_tang:
    print("Dãy tăng")
elif day_giam:
    print("Dãy Giảm")
else:
    print("Vô danh")
# Out:
# Dãy Giảm
